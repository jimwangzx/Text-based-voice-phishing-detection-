# %%
# %load_ext autoreload  
# 외부에서 import한 모듈에 수정사항 발생 시 자동 리로드
# %autoreload 2         
# 파이썬 코드를 실행하기 전에 항상 모든 모듈을 Reload하라

# %%
from Voice_Phishing import voice_detection as vd
file_path = '' # 파일 경로 담기
vp = vd.voice(file_path)
vp.result()
# Out:
# test_voice/보이스피싱\대출사기 1.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 10.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 10.wav
# Error
# Error
# ▶ 보이스피싱 확률 : 1.00% [안전]
#
#
# test_voice/보이스피싱\대출사기 11.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 12.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 13.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 14.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 15.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 16.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 17.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 17.wav
# Error
# Error
# ▶ 보이스피싱 확률 : 1.00% [안전]
#
#
# test_voice/보이스피싱\대출사기 18.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 19.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 2.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# test_voice/보이스피싱\대출사기 20.mp3
# ▶ 보이스피싱 확률 : 100.00% [위험]
#
#
# ...
